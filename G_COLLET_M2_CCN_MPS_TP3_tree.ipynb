# %%
# Par souci de simplicification, le code ici, ne s'appuie que sur la librairie 
# fournie dans le cadre du TP (mobilechelonian).

# # Remarque. Le code de ce script s'appuie sur la méthode createTree() de la classe Tree disponible
# dans le fichier Arbre.py. Ainsi, le choix a été fait de déporter le code à exécuter dans cette classe. 

from mobilechelonian import Turtle
from Arbre import Tree

t = Turtle()
t.speed(10)
tree = Tree(t)
tree.createTree(150)
# Out:
# Turtle()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-eb8be1e589ba> in <module>
#       4 t.speed(10)
#       5 tree = Tree(t)
# ----> 6 tree.createTree(150)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Arbre.py in createTree(self, size)
#      13             self.turtle.forward(size/3)
#      14             self.turtle.left(30)
# ---> 15             self.createTree(size*2/3)
#      16             self.turtle.right(30)
#      17             self.turtle.forward(size/6)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Arbre.py in createTree(self, size)
#      21             self.turtle.forward(size/3)
#      22             self.turtle.right(25)
# ---> 23             self.createTree(size/2)
#      24             self.turtle.left(25)
#      25             self.turtle.forward(size/6)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Arbre.py in createTree(self, size)
#      13             self.turtle.forward(size/3)
#      14             self.turtle.left(30)
# ---> 15             self.createTree(size*2/3)
#      16             self.turtle.right(30)
#      17             self.turtle.forward(size/6)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Arbre.py in createTree(self, size)
#      13             self.turtle.forward(size/3)
#      14             self.turtle.left(30)
# ---> 15             self.createTree(size*2/3)
#      16             self.turtle.right(30)
#      17             self.turtle.forward(size/6)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Arbre.py in createTree(self, size)
#      17             self.turtle.forward(size/6)
#      18             self.turtle.right(25)
# ---> 19             self.createTree(size/2)
#      20             self.turtle.left(25)
#      21             self.turtle.forward(size/3)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Arbre.py in createTree(self, size)
#      17             self.turtle.forward(size/6)
#      18             self.turtle.right(25)
# ---> 19             self.createTree(size/2)
#      20             self.turtle.left(25)
#      21             self.turtle.forward(size/3)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Arbre.py in createTree(self, size)
#      19             self.createTree(size/2)
#      20             self.turtle.left(25)
# ---> 21             self.turtle.forward(size/3)
#      22             self.turtle.right(25)
#      23             self.createTree(size/2)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/mobilechelonian/__init__.py in forward(self, num)
#     112
#     113         self.b_change = 0
# --> 114         self._add_point()
#     115
#     116     def backward(self, num):
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/mobilechelonian/__init__.py in _add_point(self)
#     178         p = dict(p=self.pen, lc=self.color, x=self.posX, y=self.posY,
#     179                  b=self.b_change, s=self.speedVar)
# --> 180         self.points = self.points + [p]
#     181
#     182     def circle(self, radius, extent=360):
#
# ~/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# ~/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     603             if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     604                 # Send new state to front-end
# --> 605                 self.send_state(key=name)
#     606         super(Widget, self).notify_change(change)
#     607
#
# ~/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in send_state(self, key)
#     487             state, buffer_paths, buffers = _remove_buffers(state)
#     488             msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 489             self._send(msg, buffers=buffers)
#     490
#     491
#
# ~/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _send(self, msg, buffers)
#     735         """Sends a message to the model in the front-end."""
#     736         if self.comm is not None and self.comm.kernel is not None:
# --> 737             self.comm.send(data=msg, buffers=buffers)
#     738
#     739     def _repr_keys(self):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/comm/comm.py in send(self, data, metadata, buffers)
#     121         """Send a message to the frontend-side version of this comm"""
#     122         self._publish_msg('comm_msg',
# --> 123             data=data, metadata=metadata, buffers=buffers,
#     124         )
#     125
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/comm/comm.py in _publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      63         data = {} if data is None else data
#      64         metadata = {} if metadata is None else metadata
# ---> 65         content = json_clean(dict(data=data, comm_id=self.comm_id, **keys))
#      66         self.kernel.session.send(self.kernel.iopub_socket, msg_type,
#      67             content,
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     189         out = {}
#     190         for k,v in iteritems(obj):
# --> 191             out[unicode_type(k)] = json_clean(v)
#     192         return out
#     193     if isinstance(obj, datetime):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     189         out = {}
#     190         for k,v in iteritems(obj):
# --> 191             out[unicode_type(k)] = json_clean(v)
#     192         return out
#     193     if isinstance(obj, datetime):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     189         out = {}
#     190         for k,v in iteritems(obj):
# --> 191             out[unicode_type(k)] = json_clean(v)
#     192         return out
#     193     if isinstance(obj, datetime):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     175
#     176     if isinstance(obj, list):
# --> 177         return [json_clean(x) for x in obj]
#     178
#     179     if isinstance(obj, dict):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/jsonutil.py in <listcomp>(.0)
#     175
#     176     if isinstance(obj, list):
# --> 177         return [json_clean(x) for x in obj]
#     178
#     179     if isinstance(obj, dict):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     189         out = {}
#     190         for k,v in iteritems(obj):
# --> 191             out[unicode_type(k)] = json_clean(v)
#     192         return out
#     193     if isinstance(obj, datetime):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     142         return obj
#     143
# --> 144     if isinstance(obj, numbers.Integral):
#     145         # cast int to int, in case subclasses override __str__ (e.g. boost enum, #4598)
#     146         return int(obj)
#
# ~/anaconda3/lib/python3.7/abc.py in __instancecheck__(cls, instance)
#     135             return _abc_register(cls, subclass)
#     136
# --> 137         def __instancecheck__(cls, instance):
#     138             """Override for isinstance(instance, cls)."""
#     139             return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:
