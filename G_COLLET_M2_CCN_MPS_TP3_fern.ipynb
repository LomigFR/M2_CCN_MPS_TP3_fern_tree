# %%
# 2 possibilités d'environnements sont proposées au choix :
#    - la librairie mobilechelonian (module Turtle)
#    - la librairie Python turtle

# Remarque 1. Si le choix est fait d'utiliser la librairie Python turtle,
# il est possible de décommenter la ligne t.pensize(1) afin d'obtenir un dessin avec un trait plus fin.

# Remarque 2. L'utilisation de la librairie Python turtle, se traduit par l'ouverture d'une fenêtre
# à l'exécution du script. La fermeture prématurée de cette fenêtre génère un message d'erreur "Terminator" ou
# TclError, mais le script est bel et bien fonctionnel.

# Remarque 3. Le code de ce script s'appuie sur la méthode createFern() de la classe Fern disponible
# dans le fichier Fougere.py. Ainsi, le choix a été fait de déporter le code à exécuter dans cette classe. 

from mobilechelonian import Turtle
#from turtle import *

from Fougere import Fern
t = Turtle()
#t.pensize(1)
t.speed(10)
fern = Fern(t)
fern.createFern(25, 1)
# Out:
# Turtle()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-872a7ae643f1> in <module>
#      21 t.speed(10)
#      22 fern = Fern(t)
# ---> 23 fern.createFern(25, 1)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Fougere.py in createFern(self, size, sign)
#      12             self.turtle.right(70*sign)
#      13
# ---> 14             self.createFern(size*0.5, -1*sign)
#      15
#      16             self.turtle.left(70*sign)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Fougere.py in createFern(self, size, sign)
#      18             self.turtle.left(70*sign)
#      19
# ---> 20             self.createFern(size*0.5, sign)
#      21
#      22             self.turtle.right(70*sign)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Fougere.py in createFern(self, size, sign)
#      23             self.turtle.right(7*sign)
#      24
# ---> 25             self.createFern(size-1, sign)
#      26
#      27             self.turtle.left(7*sign)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Fougere.py in createFern(self, size, sign)
#      23             self.turtle.right(7*sign)
#      24
# ---> 25             self.createFern(size-1, sign)
#      26
#      27             self.turtle.left(7*sign)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/Fougere.py in createFern(self, size, sign)
#      21
#      22             self.turtle.right(70*sign)
# ---> 23             self.turtle.right(7*sign)
#      24
#      25             self.createFern(size-1, sign)
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/mobilechelonian/__init__.py in right(self, num)
#      77         self.bearing = self.bearing%360
#      78         self.b_change = num
# ---> 79         self._add_point()
#      80
#      81     def left(self, num):
#
# ~/Documents/MPS/M2_CCN_MPS_June/TPs/TP3/mobilechelonian/__init__.py in _add_point(self)
#     178         p = dict(p=self.pen, lc=self.color, x=self.posX, y=self.posY,
#     179                  b=self.b_change, s=self.speedVar)
# --> 180         self.points = self.points + [p]
#     181
#     182     def circle(self, radius, extent=360):
#
# ~/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# ~/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     603             if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     604                 # Send new state to front-end
# --> 605                 self.send_state(key=name)
#     606         super(Widget, self).notify_change(change)
#     607
#
# ~/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in send_state(self, key)
#     487             state, buffer_paths, buffers = _remove_buffers(state)
#     488             msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 489             self._send(msg, buffers=buffers)
#     490
#     491
#
# ~/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _send(self, msg, buffers)
#     735         """Sends a message to the model in the front-end."""
#     736         if self.comm is not None and self.comm.kernel is not None:
# --> 737             self.comm.send(data=msg, buffers=buffers)
#     738
#     739     def _repr_keys(self):
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/comm/comm.py in send(self, data, metadata, buffers)
#     121         """Send a message to the frontend-side version of this comm"""
#     122         self._publish_msg('comm_msg',
# --> 123             data=data, metadata=metadata, buffers=buffers,
#     124         )
#     125
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/comm/comm.py in _publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      69             parent=self.kernel._parent_header,
#      70             ident=self.topic,
# ---> 71             buffers=buffers,
#      72         )
#      73
#
# ~/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     735         if self.adapt_version:
#     736             msg = adapt(msg, self.adapt_version)
# --> 737         to_send = self.serialize(msg, ident)
#     738         to_send.extend(buffers)
#     739         longest = max([ len(s) for s in to_send ])
#
# ~/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in serialize(self, msg, ident)
#     623             content = self.none
#     624         elif isinstance(content, dict):
# --> 625             content = self.pack(content)
#     626         elif isinstance(content, bytes):
#     627             # content is already packed, as in a relayed message
#
# ~/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in <lambda>(obj)
#     101 # disallow nan, because it's not actually valid JSON
#     102 json_packer = lambda obj: jsonapi.dumps(obj, default=date_default,
# --> 103     ensure_ascii=False, allow_nan=False,
#     104 )
#     105 json_unpacker = lambda s: jsonapi.loads(s)
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/utils/jsonapi.py in dumps(o, **kwargs)
#      38         kwargs['separators'] = (',', ':')
#      39
# ---> 40     s = jsonmod.dumps(o, **kwargs)
#      41
#      42     if isinstance(s, unicode):
#
# ~/anaconda3/lib/python3.7/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# ~/anaconda3/lib/python3.7/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# ~/anaconda3/lib/python3.7/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# KeyboardInterrupt:
